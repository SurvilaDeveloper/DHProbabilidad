# %% [markdown]
# # Distribución Normal (Gaussiana)
#
# La **distribución normal** es una de las distribuciones más importantes en estadística y probabilidad. Se utiliza para modelar fenómenos naturales, errores de medición, inteligencia, alturas, etc.
#
# ---
#
# ## 📐 Función de Densidad de Probabilidad (PDF)
#
# La fórmula de la función de densidad de la normal es:
#
# $$
# f(x; \mu, \sigma) = \frac{1}{\sigma \sqrt{2\pi}} e^{ -\frac{1}{2} \left( \frac{x - \mu}{\sigma} \right)^2 }
# $$
#
# Donde:
# - $ \mu $ es la **media** (centro de la distribución).
# - $ \sigma $ es la **desviación estándar** (ancho o dispersión).
# - $ \sigma^2 $ es la **varianza**.
#
# ---
#
# ## 🧠 Propiedades
#
# - Es **simétrica** respecto a la media $ \mu $.
# - Tiene forma de **campana**.
# - La **media, mediana y moda** coinciden.
# - El 68% de los valores están dentro de $ \mu \pm \sigma $.
# - El 95% están dentro de $ \mu \pm 2\sigma $.
# - El 99.7% están dentro de $ \mu \pm 3\sigma $ (regla empírica o regla 68–95–99.7).
#
# ---
#
# ## 🧪 Distribución Normal Estándar
#
# Cuando $ \mu = 0 $ y $ \sigma = 1 $, se llama **distribución normal estándar** y su PDF es:
#
# $$
# f(z) = \frac{1}{\sqrt{2\pi}} e^{ -\frac{z^2}{2} }
# $$
#
# Donde $ z = \frac{x - \mu}{\sigma} $ es la variable tipificada.
#
# ---
#
# ## 📊 Usos comunes
#
# - Modelar errores o ruido.
# - Teorema Central del Límite: muchas distribuciones tienden a la normal si se promedian suficientes observaciones independientes.
# - Inferencia estadística (intervalos de confianza, pruebas de hipótesis, etc.).
#
# ---
#
# ## 📌 Notación
#
# Se denota como:
#
# $$
# X \sim \mathcal{N}(\mu, \sigma^2)
# $$
#
# Por ejemplo, si $ X \sim \mathcal{N}(0, 1) $, entonces es una normal estándar.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

plt.style.use('dark_background')

# Parámetros de la distribución
mu = 0       # media
sigma = 1    # desviación estándar
n = 10000    # cantidad de muestras

# Simulación de datos
samples = np.random.normal(loc=mu, scale=sigma, size=n)

# Valores para la curva teórica
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf_theoretical = norm.pdf(x, mu, sigma)

# Graficar histograma y curva teórica
plt.figure(figsize=(10, 5))
plt.hist(samples, bins=50, density=True, alpha=0.6, color='skyblue', label='Simulación')
plt.plot(x, pdf_theoretical, 'r-', lw=2, label='PDF teórica')

plt.title(f'Distribución Normal — $\\mu$ = {mu}, $\\sigma$ = {sigma}')
plt.xlabel('Valor')
plt.ylabel('Densidad')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución
mu = 50       # media
sigma = 10    # desviación estándar
n = 10000     # número de muestras

# Simulación de datos
samples = np.random.normal(loc=mu, scale=sigma, size=n)

# Valores para la curva teórica
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf_theoretical = norm.pdf(x, mu, sigma)

# Graficar histograma y curva teórica
plt.figure(figsize=(10, 5))
plt.hist(samples, bins=50, density=True, alpha=0.6, color='lightgreen', label='Simulación')
plt.plot(x, pdf_theoretical, 'r-', lw=2, label='PDF teórica')

plt.title(f'Distribución Normal — $\\mu$ = {mu}, $\\sigma$ = {sigma}')
plt.xlabel('Valor')
plt.ylabel('Densidad')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución no estándar
mu = 50
sigma = 10
n = 10000

# Simulación
samples = np.random.normal(loc=mu, scale=sigma, size=n)

# Eje x suficientemente amplio para cubrir ambas curvas
x = np.linspace(-10, mu + 4*sigma, 1000)

# PDFs
pdf_nonstd = norm.pdf(x, mu, sigma)
pdf_std = norm.pdf(x, 0, 1)

# Graficar
plt.figure(figsize=(10, 5))

# Histograma de los datos simulados (normal no estándar)
plt.hist(samples, bins=50, density=True, alpha=0.5, color='skyblue', label='Histograma (simulación)')

# Curvas teóricas
plt.plot(x, pdf_nonstd, 'b-', lw=2, label=f'Normal no estándar ($\\mu$={mu}, $\\sigma$={sigma})')
plt.plot(x, pdf_std, 'r--', lw=2, label='Normal estándar ($\\mu$=0, $\\sigma$=1)')

# Estética
plt.title('Histograma vs normales (no estándar y estándar sin escalar)')
plt.xlabel('Valor')
plt.ylabel('Densidad')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, laplace, uniform

# Rango común para todas las distribuciones
x = np.linspace(-8, 8, 1000)

# PDFs
pdf_norm = norm.pdf(x, loc=0, scale=1)
pdf_laplace = laplace.pdf(x, loc=0, scale=1 / np.sqrt(2))  # ajustamos varianza = 1
pdf_uniform = uniform.pdf(x, loc=-np.sqrt(3), scale=2*np.sqrt(3))  # varianza = 1

# Graficar
plt.figure(figsize=(10, 6))
plt.plot(x, pdf_norm, 'k-', lw=2, label='Normal estándar (mesocúrtica)')
plt.plot(x, pdf_laplace, 'b--', lw=2, label='Laplace (leptocúrtica)')
plt.plot(x, pdf_uniform, 'g-.', lw=2, label='Uniforme (platicúrtica)')

# Estética
plt.title('Distribuciones con distinta curtosis (misma varianza)')
plt.xlabel('Valor')
plt.ylabel('Densidad')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()
