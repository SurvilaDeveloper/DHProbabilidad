# %% [markdown]
# | Tipo de Gráfico           | Función en Seaborn                  | Descripción                                                      |
# |---------------------------|-------------------------------------|------------------------------------------------------------------|
# | **Distribución univariada**| `sns.histplot()`                    | Histograma con posibilidad de superponer una distribución        |
# |                           | `sns.kdeplot()`                     | Gráfico de densidad de Kernel                                     |
# |                           | `sns.displot()`                     | Gráfico de distribución de datos                                  |
# | **Distribución bivariada** | `sns.jointplot()`                   | Relación entre dos variables, con diferentes opciones de visualización|
# |                           | `sns.pairplot()`                    | Matriz de gráficos para explorar relaciones entre múltiples variables|
# | **Gráfico de cajas**       | `sns.boxplot()`                     | Boxplot mostrando la distribución de datos con caja y bigotes    |
# |                           | `sns.violinplot()`                  | Boxplot combinado con un gráfico de densidad                      |
# |                           | `sns.boxenplot()`                   | Variante del boxplot mostrando más detalles de las colas         |
# | **Gráfico de barras**      | `sns.barplot()`                     | Barra para representar la media (o alguna estadística) de una variable categórica |
# |                           | `sns.countplot()`                   | Muestra el conteo de observaciones para cada categoría            |
# | **Gráfico de puntos**      | `sns.pointplot()`                   | Muestra la media de una categoría en formato de puntos           |
# | **Gráfico de segmentos**   | `sns.stripplot()`                   | Muestra las observaciones individuales en una categoría          |
# |                           | `sns.swarmplot()`                   | Similar a stripplot, pero ajusta las posiciones para evitar superposiciones |
# | **Gráfico de regresión**   | `sns.regplot()`                     | Gráfico de dispersión con línea de regresión ajustada             |
# |                           | `sns.lmplot()`                      | Similar a `regplot()`, pero con la posibilidad de facetado       |
# | **Gráfico de dispersión**  | `sns.relplot()`                     | Gráfico de dispersión con opciones de ajuste (como regresión)    |
# | **Gráfico de matriz**      | `sns.heatmap()`                     | Muestra una matriz de valores con colores representando magnitudes |
# |                           | `sns.clustermap()`                  | Muestra una matriz de distancias o correlaciones con un clúster jerárquico |
# | **Gráfico de facetas**     | `sns.FacetGrid()`                   | Crea subgráficos en un grid para comparar distribuciones o relaciones entre variables |
# |                           | `sns.catplot()`                     | Gráficos categóricos en un grid de facetas                       |
# | **Gráfico de series temporales** | `sns.lineplot()`            | Gráfico de líneas para representar series temporales             |
# | **Gráfico de densidad**    | `sns.kdeplot()`                     | Estimación de la densidad de probabilidad de una o dos variables |
# | **Gráfico de correlación** | `sns.pairplot()`                    | Matriz de gráficos de dispersión para comparar las relaciones entre múltiples variables|

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un histograma para la columna "total_bill"
sns.histplot(tips["total_bill"], kde=True, bins=20, color="skyblue")

# Añadir título y etiquetas
plt.title('Histograma de Total Bill con KDE')
plt.xlabel('Total Bill')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un gráfico KDE para la columna "total_bill"
sns.kdeplot(tips["total_bill"], fill=True, color="green", linewidth=2)

# Añadir título y etiquetas
plt.title('Curva de Densidad de Kernel de Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Densidad')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un gráfico de distribución con histograma y KDE
sns.displot(tips["total_bill"], kde=True, bins=20, color="orange")

# Añadir título y etiquetas
plt.title('Distribución de Total Bill con Histograma y KDE')
plt.xlabel('Total Bill')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un jointplot para mostrar la relación entre "total_bill" y "tip"
sns.jointplot(x="total_bill", y="tip", data=tips, kind="scatter", color="purple")

# Añadir título
plt.suptitle('Relación entre Total Bill y Tip', y=1.05)

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un pairplot para ver las relaciones entre todas las variables numéricas
sns.pairplot(tips, hue="sex", palette="coolwarm", diag_kind="kde")

# Añadir título
plt.suptitle('Matriz de Gráficos de Dispersión de Tips', y=1.02)

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un boxplot para la columna "total_bill" agrupado por la variable "sex"
sns.boxplot(x="sex", y="total_bill", data=tips, hue="sex", palette="coolwarm", legend=False)

# Añadir título y etiquetas
plt.title('Distribución de Total Bill por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Total Bill')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un violinplot para la columna "total_bill" agrupado por la variable "sex"
sns.violinplot(x="sex", y="total_bill", data=tips, hue="sex", palette="coolwarm", legend=False)

# Añadir título y etiquetas
plt.title('Distribución de Total Bill por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Total Bill')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un boxenplot para la columna "total_bill" agrupado por la variable "sex"
sns.boxenplot(x="sex", y="total_bill", data=tips, hue="sex", palette="coolwarm")

# Añadir título y etiquetas
plt.title('Distribución de Total Bill por Sexo (Boxenplot)')
plt.xlabel('Sexo')
plt.ylabel('Total Bill')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un barplot para mostrar la media de "total_bill" agrupado por la variable "sex" y coloreado por "sex"
sns.barplot(x="sex", y="total_bill", data=tips, hue="sex", palette="coolwarm")

# Añadir título y etiquetas
plt.title('Promedio de Total Bill por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Promedio de Total Bill')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un countplot para contar el número de registros en cada categoría de "sex"
sns.countplot(x="sex", data=tips, hue="sex", palette="coolwarm", legend=False)

# Añadir título y etiquetas
plt.title('Número de Registros por Sexo')
plt.xlabel('Sexo')
plt.ylabel('Número de Registros')

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un pointplot para visualizar la propina media por día, diferenciando por sexo
sns.pointplot(x="day", y="tip", hue="sex", data=tips, palette="Set2")

# Añadir título y etiquetas
plt.title("Propina media por día, diferenciada por sexo")
plt.xlabel("Día de la semana")
plt.ylabel("Propina promedio")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un stripplot para visualizar la dispersión de los valores de propina según el día, diferenciando por sexo
sns.stripplot(x="day", y="tip", hue="sex", data=tips, palette="Set1", dodge=True)

# Añadir título y etiquetas
plt.title("Dispersión de propinas por día y sexo")
plt.xlabel("Día de la semana")
plt.ylabel("Propina")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar un conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un swarmplot para visualizar la distribución de propinas por día, diferenciando por sexo
sns.swarmplot(x="day", y="tip", hue="sex", data=tips, palette="Dark2", dodge=True)

# Añadir título y etiquetas
plt.title("Distribución de propinas por día y sexo (Swarmplot)")
plt.xlabel("Día de la semana")
plt.ylabel("Propina")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un regplot para visualizar la relación entre total_bill y tip
sns.regplot(x="total_bill", y="tip", data=tips, scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

# Añadir título y etiquetas
plt.title("Relación entre total_bill y tip con línea de regresión")
plt.xlabel("Total de la cuenta")
plt.ylabel("Propina")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un lmplot para mostrar la relación entre total_bill y tip, diferenciando por sexo
sns.lmplot(x="total_bill", y="tip", hue="sex", data=tips, palette="Set1", height=6, aspect=1.2)

# Añadir título y ajustar el diseño
plt.suptitle("Relación entre Total de la Cuenta y Propina, diferenciada por Sexo", y=1.03)
plt.xlabel("Total de la cuenta")
plt.ylabel("Propina")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un gráfico de dispersión con relplot, diferenciando por sexo y usando columnas para el tiempo
sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="sex",
    col="time",
    kind="scatter",
    palette="Set2",
    height=5,
    aspect=1
)

# Añadir un título general al gráfico
plt.subplots_adjust(top=0.85)
plt.suptitle("Relación entre Total de la Cuenta y Propina por Sexo y Momento del Día")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Calcular la matriz de correlación entre variables numéricas
corr = tips.corr(numeric_only=True)

# Crear el heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Añadir título
plt.title("Mapa de calor de la correlación entre variables numéricas")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Calcular la matriz de correlación entre variables numéricas
corr = tips.corr(numeric_only=True)

# Crear el clustermap
sns.clustermap(corr, annot=True, cmap="vlag", fmt=".2f", linewidths=0.5)

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un objeto FacetGrid que separa por día y sexo
g = sns.FacetGrid(tips, col="day", row="sex", margin_titles=True)

# Mapear un gráfico de dispersión (scatterplot) en cada subgráfico
g.map(sns.scatterplot, "total_bill", "tip", alpha=0.7)

# Añadir títulos y ajustar diseño
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Propina vs Total de la Cuenta por Día y Sexo")

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un gráfico de caja (boxplot) por día y sexo con catplot
sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="sex",
    kind="box",
    height=5,
    aspect=1.2,
    palette="pastel"
)

# Añadir un título general
plt.suptitle("Distribución del Total de la Cuenta por Día y Sexo", y=1.05)

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
fmri = sns.load_dataset("fmri")

# Crear un gráfico de líneas para mostrar la respuesta cerebral a lo largo del tiempo
sns.lineplot(
    data=fmri,
    x="timepoint",
    y="signal",
    hue="event",
    style="region",
    markers=True,
    dashes=False,
    palette="tab10"
)

# Añadir título y etiquetas
plt.title("Respuesta cerebral a lo largo del tiempo")
plt.xlabel("Momento")
plt.ylabel("Intensidad de la señal")

# Mostrar gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
tips = sns.load_dataset("tips")

# Crear un KDE plot para la variable 'total_bill' separando por sexo
sns.kdeplot(
    data=tips,
    x="total_bill",
    hue="sex",
    fill=True,
    common_norm=False,
    alpha=0.5,
    linewidth=2,
    palette="Set2"
)

# Añadir título y etiquetas
plt.title("Distribución de total_bill por sexo (KDE)")
plt.xlabel("Total de la cuenta")
plt.ylabel("Densidad")

# Mostrar gráfico
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el conjunto de datos de ejemplo
iris = sns.load_dataset("iris")

# Crear un pairplot para visualizar las relaciones entre todas las variables numéricas
sns.pairplot(
    iris,
    hue="species",  # Diferenciar por especie
    palette="Set1",  # Colores para las especies
    markers=["o", "s", "D"],  # Diferentes marcadores para cada especie
    height=2.5,  # Tamaño de cada subgráfico
    corner=True  # Elimina los gráficos duplicados en la parte superior
)

# Añadir título general
plt.suptitle("Pairplot de las relaciones entre variables del dataset Iris", y=1.02)

# Mostrar el gráfico
plt.show()
